# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL.Image
import networkx as nx
import pandas as pd
import string

from functions.genome_topology import open_pdb
from functions.genome_topology import select_chrom
from functions.genome_topology import geom_distance
from functions.genome_topology import make_graph
from functions.genome_topology import fractal_dimension
from functions.genome_topology import get_matrix
from functions.genome_topology import normalize_psc

# %%
def load_pdb(file_path):
    """
    Load a PDB file and extract atom coordinates.

    Parameters:
    file_path (str): Path to the PDB file.

    Returns:
    int: The number of atoms.
    list of tuples: List where each tuple represents the coordinates (x, y, z) of an atom.
    """
    coordinates = []  # List to hold the coordinates
    with open(file_path, 'r') as pdb_file:
        for line in pdb_file:
            if line.startswith('ATOM') or line.startswith('HETATM'):
                # Extract the x, y, and z coordinates for each atom
                x = float(line[30:38].strip())
                y = float(line[38:46].strip())
                z = float(line[46:54].strip())
                coordinates.append((x, y, z))  # Add the coordinates as a tuple to the list
    
    n = len(coordinates)  # Number of atoms
    return n, coordinates  # Return the number of atoms and the list of coordinates


def main(parameters, path_data,path_results):
    letters=list(string.ascii_lowercase)
    chr_vec=['chr {}'.format(letter) for letter in letters[:n_all_chr]]
    cell=path_data[-5:] 
    
    for n_chr, chrom in enumerate(chr_vec):
        print('analyzing the chrom',chrom)
        
        # n, coord= select_chrom(n_chr, path_data) 
        n, coord_list = load_pdb(path_data)
        coord = np.array(coord_list)  # Convert list of tuples into NumPy array       
        iterations=int(n/parameters['resolution'])
        start_iteration= int(parameters['init']/parameters['resolution'])
        
        Parallel=np.zeros(iterations)
        Series=np.zeros(iterations)
        Cross=np.zeros(iterations)
        Dim_fractal=np.zeros(iterations)
        r2_fractalfit=np.zeros(iterations)
        N_contacts=np.zeros(iterations)
        clustering= np.zeros(iterations)
        
        for t in range(start_iteration,iterations):
            
            n_atoms=int(resolution*(t+1))
            print('analyzing the n_tom',n_atoms)
            coord_cut=coord[0: n_atoms]  
            dist, N_contacts[t], index=geom_distance(coord_cut, 
            parameters['cutoff'], parameters['neighbors'])
             
            try:
                
                mat, stats = get_matrix(index,chrom)
                Parallel[t], Series[t], Cross[t]=normalize_psc(stats,N_contacts[t])
                Dim_fractal[t], r2_fractalfit[t]=fractal_dimension(mat, plot_fig=0)
                G=make_graph(index)
                clustering[t]= nx.average_clustering(G)
            except:
                print('WARNING: NOT ENOUGH CONTACTS FOR ANALYSIS')
        
        topology_parameters = {'Parallel (%)':Parallel, 'Series (%)':Series, 
        'Cross (%)':Cross, 'N contacts': N_contacts,
        'Fractal dimension':Dim_fractal, 'r squared': r2_fractalfit,
        'Clustering': clustering}
        topology_parameters= pd.DataFrame(topology_parameters)
        topology_parameters.to_csv('{}/Top_parameters_{}_{}.csv'.format(
            path_results, cell, chrom))

     
        
        
r_cutoff=1.0
neighbours=1
n_all_chr=20
resolution=5
start_from= 0
parameters={'cutoff':r_cutoff,'neighbors': neighbours,'N chromosomes': 
              n_all_chr, 'resolution': resolution, 'init': start_from}

# %%
import os

folder = './pdb/'
cell_ids = [f for f in os.listdir(folder) if f.startswith('Cell')]

for cell_id in cell_ids:
    path_data = os.path.join(folder, cell_id, 'chr_a.pdb')
    path_results = os.path.join('results', 'cumulative analysis', cell_id)
    
    if not os.path.exists(path_results):
        os.makedirs(path_results)
    
    main(parameters, path_data, path_results)
# Out:
# analyzing the chrom chr a
# analyzing the n_tom 5
# WARNING: NOT ENOUGH CONTACTS FOR ANALYSIS
# analyzing the n_tom 10
# analyzing the n_tom 15
# analyzing the n_tom 20
# analyzing the n_tom 25
# analyzing the n_tom 30
# analyzing the n_tom 35
# analyzing the n_tom 40
# analyzing the n_tom 45
# analyzing the n_tom 50
# analyzing the n_tom 55
# analyzing the n_tom 60
# analyzing the n_tom 65
# analyzing the n_tom 70
# analyzing the n_tom 75
# analyzing the n_tom 80
# analyzing the n_tom 85
# analyzing the n_tom 90
# analyzing the n_tom 95
# analyzing the n_tom 100
# analyzing the n_tom 105
# analyzing the n_tom 110
# analyzing the n_tom 115
# analyzing the n_tom 120
# analyzing the n_tom 125
# analyzing the n_tom 130
# analyzing the n_tom 135
# analyzing the n_tom 140
# analyzing the n_tom 145
# analyzing the n_tom 150
# analyzing the n_tom 155
# analyzing the n_tom 160
# analyzing the n_tom 165
# analyzing the n_tom 170
# analyzing the n_tom 175
# analyzing the n_tom 180
# analyzing the n_tom 185
# analyzing the n_tom 190
# analyzing the n_tom 195
# analyzing the n_tom 200
# analyzing the n_tom 205
# analyzing the n_tom 210
# analyzing the n_tom 215
# analyzing the n_tom 220
# analyzing the n_tom 225
# analyzing the n_tom 230
# analyzing the n_tom 235
# analyzing the n_tom 240
# analyzing the n_tom 245
# analyzing the n_tom 250
# analyzing the n_tom 255
# analyzing the n_tom 260
# analyzing the n_tom 265
# analyzing the n_tom 270
# analyzing the n_tom 275
# analyzing the n_tom 280
# analyzing the n_tom 285
# analyzing the n_tom 290
# analyzing the n_tom 295
# analyzing the n_tom 300
# analyzing the n_tom 305
# analyzing the n_tom 310
# analyzing the n_tom 315
# analyzing the n_tom 320
# analyzing the n_tom 325
# analyzing the n_tom 330
# analyzing the n_tom 335
# analyzing the n_tom 340
# analyzing the n_tom 345
# analyzing the n_tom 350
# analyzing the n_tom 355
# analyzing the n_tom 360
# analyzing the n_tom 365
# analyzing the n_tom 370
# analyzing the n_tom 375
# analyzing the n_tom 380
# analyzing the n_tom 385
# analyzing the n_tom 390
# analyzing the n_tom 395
# analyzing the n_tom 400
# analyzing the n_tom 405
# analyzing the n_tom 410
# analyzing the n_tom 415
# analyzing the n_tom 420
# analyzing the n_tom 425
# analyzing the n_tom 430
# analyzing the n_tom 435
# analyzing the n_tom 440
# analyzing the n_tom 445
# analyzing the n_tom 450
# analyzing the n_tom 455
# analyzing the n_tom 460
# analyzing the n_tom 465
# analyzing the n_tom 470
# analyzing the n_tom 475
# analyzing the n_tom 480
# analyzing the n_tom 485
# analyzing the n_tom 490
# analyzing the n_tom 495
# analyzing the n_tom 500
# analyzing the n_tom 505
# analyzing the n_tom 510
# analyzing the n_tom 515
# analyzing the n_tom 520
# analyzing the n_tom 525
# analyzing the n_tom 530
# analyzing the n_tom 535
# analyzing the n_tom 540
# analyzing the n_tom 545
# analyzing the n_tom 550
# analyzing the n_tom 555
# analyzing the n_tom 560
# analyzing the n_tom 565
# analyzing the n_tom 570
# analyzing the n_tom 575
# analyzing the n_tom 580
# analyzing the n_tom 585
# analyzing the n_tom 590
# analyzing the n_tom 595
# analyzing the n_tom 600
# analyzing the n_tom 605
# analyzing the n_tom 610
# analyzing the n_tom 615
# analyzing the n_tom 620
# analyzing the n_tom 625
# analyzing the n_tom 630
# analyzing the n_tom 635
# analyzing the n_tom 640
# analyzing the n_tom 645
# analyzing the n_tom 650
# analyzing the n_tom 655
# analyzing the n_tom 660
# analyzing the n_tom 665
# analyzing the n_tom 670
# analyzing the n_tom 675
# analyzing the n_tom 680
# analyzing the n_tom 685
# analyzing the n_tom 690
# analyzing the n_tom 695
# analyzing the n_tom 700
# analyzing the n_tom 705
# analyzing the n_tom 710
# analyzing the n_tom 715
# analyzing the n_tom 720
# analyzing the n_tom 725
# analyzing the n_tom 730
# analyzing the n_tom 735
# analyzing the n_tom 740
# analyzing the n_tom 745
# analyzing the n_tom 750
# analyzing the n_tom 755
# analyzing the n_tom 760
# analyzing the n_tom 765
# analyzing the n_tom 770
# analyzing the n_tom 775
# analyzing the n_tom 780
# analyzing the n_tom 785
# analyzing the n_tom 790
# analyzing the n_tom 795
# analyzing the n_tom 800
# analyzing the n_tom 805
# analyzing the n_tom 810
# analyzing the n_tom 815
# analyzing the n_tom 820
# analyzing the n_tom 825
# analyzing the n_tom 830
# analyzing the n_tom 835
# analyzing the n_tom 840
# analyzing the n_tom 845
# analyzing the n_tom 850
# analyzing the n_tom 855
# analyzing the n_tom 860
# analyzing the n_tom 865
# analyzing the n_tom 870
# analyzing the n_tom 875
# analyzing the n_tom 880
# analyzing the n_tom 885
# analyzing the n_tom 890
# analyzing the n_tom 895
# analyzing the n_tom 900
# analyzing the n_tom 905
# analyzing the n_tom 910
# analyzing the n_tom 915
# analyzing the n_tom 920
# analyzing the n_tom 925
# analyzing the n_tom 930
# analyzing the n_tom 935
# analyzing the n_tom 940
# analyzing the n_tom 945
# analyzing the n_tom 950
# analyzing the n_tom 955
# analyzing the n_tom 960
# analyzing the n_tom 965
# analyzing the n_tom 970
# analyzing the n_tom 975
# analyzing the n_tom 980
# analyzing the n_tom 985
# analyzing the n_tom 990
# analyzing the n_tom 995
# analyzing the n_tom 1000
# analyzing the n_tom 1005
# analyzing the n_tom 1010
# analyzing the n_tom 1015
# analyzing the n_tom 1020
# analyzing the n_tom 1025
# analyzing the n_tom 1030
# analyzing the n_tom 1035
# analyzing the n_tom 1040
# analyzing the n_tom 1045
# analyzing the n_tom 1050
# analyzing the n_tom 1055
# analyzing the n_tom 1060
# analyzing the n_tom 1065
# analyzing the n_tom 1070
# analyzing the n_tom 1075
# analyzing the n_tom 1080
# analyzing the n_tom 1085
# analyzing the n_tom 1090
# analyzing the n_tom 1095
# analyzing the n_tom 1100
# analyzing the n_tom 1105
# analyzing the n_tom 1110
# analyzing the n_tom 1115
# analyzing the n_tom 1120
# analyzing the n_tom 1125
# analyzing the n_tom 1130
# analyzing the n_tom 1135
# analyzing the n_tom 1140
# analyzing the n_tom 1145
# analyzing the n_tom 1150
# analyzing the n_tom 1155
# analyzing the n_tom 1160
# analyzing the n_tom 1165
# analyzing the n_tom 1170
# analyzing the n_tom 1175
# analyzing the n_tom 1180
# analyzing the n_tom 1185
# analyzing the n_tom 1190
# analyzing the n_tom 1195
# analyzing the n_tom 1200
# analyzing the n_tom 1205
# analyzing the n_tom 1210
# analyzing the n_tom 1215
# analyzing the n_tom 1220
# analyzing the n_tom 1225
# analyzing the n_tom 1230
# analyzing the n_tom 1235
# analyzing the n_tom 1240
# analyzing the n_tom 1245
# analyzing the n_tom 1250
# analyzing the n_tom 1255
# analyzing the n_tom 1260
# analyzing the n_tom 1265
# analyzing the n_tom 1270
# analyzing the n_tom 1275
# analyzing the n_tom 1280
# analyzing the n_tom 1285
# analyzing the n_tom 1290
# analyzing the n_tom 1295
# analyzing the n_tom 1300
# analyzing the n_tom 1305
# analyzing the n_tom 1310
# analyzing the n_tom 1315
# analyzing the n_tom 1320
# analyzing the n_tom 1325
# analyzing the n_tom 1330
# analyzing the n_tom 1335
# analyzing the n_tom 1340
# analyzing the n_tom 1345
# analyzing the n_tom 1350
# analyzing the n_tom 1355
# analyzing the n_tom 1360
# analyzing the n_tom 1365
# analyzing the n_tom 1370
# analyzing the n_tom 1375
# analyzing the n_tom 1380
# analyzing the n_tom 1385
# analyzing the n_tom 1390
# analyzing the n_tom 1395
# analyzing the n_tom 1400
# analyzing the n_tom 1405
# analyzing the n_tom 1410
# analyzing the n_tom 1415
# analyzing the n_tom 1420
# analyzing the n_tom 1425
# analyzing the n_tom 1430
# analyzing the n_tom 1435
# analyzing the n_tom 1440
# analyzing the n_tom 1445
# analyzing the n_tom 1450
# analyzing the n_tom 1455
# analyzing the n_tom 1460
# analyzing the n_tom 1465
# analyzing the n_tom 1470
# analyzing the n_tom 1475
# analyzing the n_tom 1480
# analyzing the n_tom 1485
# analyzing the n_tom 1490
# analyzing the n_tom 1495
# analyzing the n_tom 1500
# analyzing the n_tom 1505
# analyzing the n_tom 1510
# analyzing the n_tom 1515
# analyzing the n_tom 1520
# analyzing the n_tom 1525
# analyzing the n_tom 1530
# analyzing the n_tom 1535
# analyzing the n_tom 1540
# analyzing the n_tom 1545
# analyzing the n_tom 1550
# analyzing the n_tom 1555
# analyzing the n_tom 1560
# analyzing the n_tom 1565
# analyzing the n_tom 1570
# analyzing the n_tom 1575
# analyzing the n_tom 1580
# analyzing the n_tom 1585
# analyzing the n_tom 1590
# analyzing the n_tom 1595
# analyzing the n_tom 1600
# analyzing the n_tom 1605
# analyzing the n_tom 1610
# analyzing the n_tom 1615
# analyzing the n_tom 1620
# analyzing the n_tom 1625
# analyzing the n_tom 1630
# analyzing the n_tom 1635
# analyzing the n_tom 1640
# analyzing the n_tom 1645
# analyzing the n_tom 1650
# analyzing the n_tom 1655
# analyzing the n_tom 1660
# analyzing the n_tom 1665
# analyzing the n_tom 1670
# analyzing the n_tom 1675
# analyzing the n_tom 1680
# analyzing the n_tom 1685
# analyzing the n_tom 1690
# analyzing the n_tom 1695
# analyzing the n_tom 1700
# analyzing the n_tom 1705
# analyzing the n_tom 1710
# analyzing the n_tom 1715
# analyzing the n_tom 1720
# analyzing the n_tom 1725
# analyzing the n_tom 1730
# analyzing the n_tom 1735
# analyzing the n_tom 1740
# analyzing the n_tom 1745
# analyzing the n_tom 1750
# analyzing the n_tom 1755
# analyzing the n_tom 1760
# analyzing the n_tom 1765
# analyzing the n_tom 1770
# analyzing the n_tom 1775
# analyzing the n_tom 1780
# analyzing the n_tom 1785
# analyzing the n_tom 1790
# analyzing the n_tom 1795
# analyzing the n_tom 1800
# analyzing the n_tom 1805
# analyzing the n_tom 1810
# analyzing the n_tom 1815
# analyzing the n_tom 1820
# analyzing the n_tom 1825
# analyzing the n_tom 1830
# analyzing the n_tom 1835
# analyzing the n_tom 1840
# analyzing the n_tom 1845
# analyzing the n_tom 1850
# analyzing the n_tom 1855
# analyzing the n_tom 1860
# analyzing the n_tom 1865
# analyzing the n_tom 1870
# analyzing the n_tom 1875
# analyzing the n_tom 1880
# analyzing the n_tom 1885
# analyzing the n_tom 1890
# analyzing the n_tom 1895
# analyzing the n_tom 1900
# analyzing the n_tom 1905
# analyzing the n_tom 1910
# analyzing the n_tom 1915
# analyzing the n_tom 1920
# analyzing the n_tom 1925
# analyzing the n_tom 1930
# analyzing the n_tom 1935
# analyzing the n_tom 1940
# analyzing the n_tom 1945
# analyzing the n_tom 1950
# analyzing the n_tom 1955
# analyzing the n_tom 1960
# analyzing the n_tom 1965
# analyzing the n_tom 1970
# analyzing the n_tom 1975
# analyzing the n_tom 1980
# analyzing the n_tom 1985
# analyzing the n_tom 1990
# analyzing the n_tom 1995
# analyzing the n_tom 2000
# analyzing the n_tom 2005
# analyzing the n_tom 2010
# analyzing the n_tom 2015
# analyzing the n_tom 2020
# analyzing the n_tom 2025
# analyzing the n_tom 2030
# analyzing the n_tom 2035
# analyzing the n_tom 2040
# analyzing the n_tom 2045
# analyzing the n_tom 2050
# analyzing the n_tom 2055
# analyzing the n_tom 2060
# analyzing the n_tom 2065
# analyzing the n_tom 2070
# analyzing the n_tom 2075
# analyzing the n_tom 2080
# analyzing the n_tom 2085
# analyzing the n_tom 2090
# analyzing the n_tom 2095
# analyzing the n_tom 2100
# analyzing the n_tom 2105
# analyzing the n_tom 2110
# analyzing the n_tom 2115
# analyzing the n_tom 2120
# analyzing the n_tom 2125
# analyzing the n_tom 2130
# analyzing the n_tom 2135
# analyzing the n_tom 2140
# analyzing the n_tom 2145
# analyzing the n_tom 2150
# analyzing the n_tom 2155
# analyzing the n_tom 2160
# analyzing the n_tom 2165
# analyzing the n_tom 2170
# analyzing the n_tom 2175
# analyzing the n_tom 2180
# analyzing the n_tom 2185
# analyzing the n_tom 2190
# analyzing the n_tom 2195
# analyzing the n_tom 2200
# analyzing the n_tom 2205
# analyzing the n_tom 2210
# analyzing the n_tom 2215
# analyzing the n_tom 2220
# analyzing the n_tom 2225
# analyzing the n_tom 2230
# analyzing the n_tom 2235
# analyzing the n_tom 2240
# analyzing the n_tom 2245
# analyzing the n_tom 2250
# analyzing the n_tom 2255
# analyzing the n_tom 2260
# analyzing the n_tom 2265
# analyzing the n_tom 2270
# analyzing the n_tom 2275
# analyzing the n_tom 2280
# analyzing the n_tom 2285
# analyzing the n_tom 2290
# analyzing the n_tom 2295
# analyzing the n_tom 2300
# analyzing the n_tom 2305
# analyzing the n_tom 2310
# analyzing the n_tom 2315
# analyzing the n_tom 2320
# analyzing the n_tom 2325
# analyzing the n_tom 2330
# analyzing the n_tom 2335
# analyzing the n_tom 2340
# analyzing the n_tom 2345
# analyzing the n_tom 2350
# analyzing the n_tom 2355
# analyzing the n_tom 2360
# analyzing the n_tom 2365
# analyzing the n_tom 2370
# analyzing the n_tom 2375
# analyzing the n_tom 2380
# analyzing the n_tom 2385
# analyzing the n_tom 2390
# analyzing the n_tom 2395
# analyzing the n_tom 2400
# analyzing the n_tom 2405
# analyzing the n_tom 2410
# analyzing the n_tom 2415
# analyzing the n_tom 2420
# analyzing the n_tom 2425
# analyzing the n_tom 2430
# analyzing the n_tom 2435
# analyzing the n_tom 2440
# analyzing the n_tom 2445
# analyzing the n_tom 2450
# analyzing the n_tom 2455
# analyzing the n_tom 2460
# analyzing the n_tom 2465
# analyzing the n_tom 2470
# analyzing the n_tom 2475
# analyzing the n_tom 2480
# analyzing the n_tom 2485
# analyzing the n_tom 2490
# analyzing the n_tom 2495
# analyzing the n_tom 2500
# analyzing the n_tom 2505
# analyzing the n_tom 2510
# analyzing the n_tom 2515
# analyzing the n_tom 2520
# analyzing the n_tom 2525
# analyzing the n_tom 2530
# analyzing the n_tom 2535
# analyzing the n_tom 2540
# analyzing the n_tom 2545
# analyzing the n_tom 2550
# analyzing the n_tom 2555
# analyzing the n_tom 2560
# analyzing the n_tom 2565
# analyzing the n_tom 2570
# analyzing the n_tom 2575
# analyzing the n_tom 2580
# analyzing the n_tom 2585
# analyzing the n_tom 2590
# analyzing the n_tom 2595
# analyzing the n_tom 2600
# analyzing the n_tom 2605
# analyzing the n_tom 2610
# analyzing the n_tom 2615
# analyzing the n_tom 2620
# analyzing the n_tom 2625
# analyzing the n_tom 2630
# analyzing the n_tom 2635
# analyzing the n_tom 2640
# analyzing the n_tom 2645
# analyzing the n_tom 2650
# analyzing the n_tom 2655
# analyzing the n_tom 2660
# analyzing the n_tom 2665
# analyzing the n_tom 2670
# analyzing the n_tom 2675
# analyzing the n_tom 2680
# analyzing the n_tom 2685
# analyzing the n_tom 2690
# analyzing the n_tom 2695
# analyzing the n_tom 2700
# analyzing the n_tom 2705
# analyzing the n_tom 2710
# analyzing the n_tom 2715
# analyzing the n_tom 2720
# analyzing the n_tom 2725
# analyzing the n_tom 2730
# analyzing the n_tom 2735
# analyzing the n_tom 2740
# analyzing the n_tom 2745
# analyzing the n_tom 2750
# analyzing the n_tom 2755
# analyzing the n_tom 2760
# analyzing the n_tom 2765
# analyzing the n_tom 2770
# analyzing the n_tom 2775
# analyzing the n_tom 2780
# analyzing the n_tom 2785
# analyzing the n_tom 2790
# analyzing the n_tom 2795
# analyzing the n_tom 2800
# analyzing the n_tom 2805
# analyzing the n_tom 2810
# analyzing the n_tom 2815
# analyzing the n_tom 2820
# analyzing the n_tom 2825
# analyzing the n_tom 2830
# analyzing the n_tom 2835
# analyzing the n_tom 2840
# analyzing the n_tom 2845
# analyzing the n_tom 2850
# analyzing the n_tom 2855
# analyzing the n_tom 2860
# analyzing the n_tom 2865
# analyzing the n_tom 2870
# analyzing the n_tom 2875
# analyzing the n_tom 2880
# analyzing the n_tom 2885
# analyzing the n_tom 2890
# analyzing the n_tom 2895
# analyzing the n_tom 2900
# analyzing the n_tom 2905
# analyzing the n_tom 2910
# analyzing the n_tom 2915
# analyzing the n_tom 2920
# analyzing the n_tom 2925
# analyzing the n_tom 2930
# analyzing the n_tom 2935
# analyzing the n_tom 2940
# analyzing the n_tom 2945
# analyzing the n_tom 2950
# analyzing the n_tom 2955
# analyzing the n_tom 2960
# analyzing the n_tom 2965
# analyzing the n_tom 2970
# analyzing the n_tom 2975
# analyzing the n_tom 2980
# analyzing the n_tom 2985
# analyzing the n_tom 2990
# analyzing the n_tom 2995
# analyzing the n_tom 3000
# analyzing the n_tom 3005
# analyzing the n_tom 3010
# analyzing the n_tom 3015
# analyzing the n_tom 3020
# analyzing the n_tom 3025
# analyzing the n_tom 3030
# analyzing the n_tom 3035
# analyzing the n_tom 3040
# analyzing the n_tom 3045
# analyzing the n_tom 3050
# analyzing the n_tom 3055
# analyzing the n_tom 3060
# analyzing the n_tom 3065
# analyzing the n_tom 3070
# analyzing the n_tom 3075
# analyzing the n_tom 3080
# analyzing the n_tom 3085
# analyzing the n_tom 3090
# analyzing the n_tom 3095
# analyzing the n_tom 3100
# analyzing the n_tom 3105
# analyzing the n_tom 3110
# analyzing the n_tom 3115
# analyzing the n_tom 3120
# analyzing the n_tom 3125
# analyzing the n_tom 3130
# analyzing the n_tom 3135
# analyzing the n_tom 3140
# analyzing the n_tom 3145
# analyzing the n_tom 3150
# analyzing the n_tom 3155
# analyzing the n_tom 3160
# analyzing the n_tom 3165
# analyzing the n_tom 3170
# analyzing the n_tom 3175
# analyzing the n_tom 3180
# analyzing the n_tom 3185
# analyzing the n_tom 3190
# analyzing the n_tom 3195
# analyzing the n_tom 3200
# analyzing the n_tom 3205
# analyzing the n_tom 3210
# analyzing the n_tom 3215
# analyzing the n_tom 3220
# analyzing the n_tom 3225
# analyzing the n_tom 3230
# analyzing the n_tom 3235
# analyzing the n_tom 3240
# analyzing the n_tom 3245
# analyzing the n_tom 3250
# analyzing the n_tom 3255
# analyzing the n_tom 3260
# analyzing the n_tom 3265
# analyzing the n_tom 3270
# analyzing the n_tom 3275
# analyzing the n_tom 3280
# analyzing the n_tom 3285
# analyzing the n_tom 3290
# analyzing the n_tom 3295
# analyzing the n_tom 3300
# analyzing the n_tom 3305
# analyzing the n_tom 3310
# analyzing the n_tom 3315
# analyzing the n_tom 3320
# analyzing the n_tom 3325
# analyzing the n_tom 3330
# analyzing the n_tom 3335
# analyzing the n_tom 3340
# analyzing the n_tom 3345
# analyzing the n_tom 3350
# analyzing the n_tom 3355
# analyzing the n_tom 3360
# analyzing the n_tom 3365
# analyzing the n_tom 3370
# analyzing the n_tom 3375
# analyzing the n_tom 3380
# analyzing the n_tom 3385
# analyzing the n_tom 3390
# analyzing the n_tom 3395
# analyzing the n_tom 3400
# analyzing the n_tom 3405
# analyzing the n_tom 3410
# analyzing the n_tom 3415
# analyzing the n_tom 3420
# analyzing the n_tom 3425
# analyzing the n_tom 3430
# analyzing the n_tom 3435
# analyzing the n_tom 3440
# analyzing the n_tom 3445
# analyzing the n_tom 3450
# analyzing the n_tom 3455
# analyzing the n_tom 3460
# analyzing the n_tom 3465
# analyzing the n_tom 3470
# analyzing the n_tom 3475
# analyzing the n_tom 3480
# analyzing the n_tom 3485
# analyzing the n_tom 3490
# analyzing the n_tom 3495
# analyzing the n_tom 3500
# analyzing the n_tom 3505
# analyzing the n_tom 3510
# analyzing the n_tom 3515
# analyzing the n_tom 3520
# analyzing the n_tom 3525
# analyzing the n_tom 3530
# analyzing the n_tom 3535
# analyzing the n_tom 3540
# analyzing the n_tom 3545
# analyzing the n_tom 3550
# analyzing the n_tom 3555
# analyzing the n_tom 3560
# analyzing the n_tom 3565
# analyzing the n_tom 3570
# analyzing the n_tom 3575
# analyzing the n_tom 3580
# analyzing the n_tom 3585
# analyzing the n_tom 3590
# analyzing the n_tom 3595
# analyzing the n_tom 3600
# analyzing the n_tom 3605
# analyzing the n_tom 3610
# analyzing the n_tom 3615
# analyzing the n_tom 3620
# analyzing the n_tom 3625
# analyzing the n_tom 3630
# analyzing the n_tom 3635
# analyzing the n_tom 3640
# analyzing the n_tom 3645
# analyzing the n_tom 3650
# analyzing the n_tom 3655
# analyzing the n_tom 3660
# analyzing the n_tom 3665
# analyzing the n_tom 3670
# analyzing the n_tom 3675
# analyzing the n_tom 3680
# analyzing the n_tom 3685
# analyzing the n_tom 3690
# analyzing the n_tom 3695
# analyzing the n_tom 3700
# analyzing the n_tom 3705
# analyzing the n_tom 3710
# analyzing the n_tom 3715
# analyzing the n_tom 3720
# analyzing the n_tom 3725
# analyzing the n_tom 3730
# analyzing the n_tom 3735
# analyzing the n_tom 3740
# analyzing the n_tom 3745
# analyzing the n_tom 3750
# analyzing the n_tom 3755
# analyzing the n_tom 3760
# analyzing the n_tom 3765
# analyzing the n_tom 3770
# analyzing the n_tom 3775
# analyzing the n_tom 3780
# analyzing the n_tom 3785
# analyzing the n_tom 3790
# analyzing the n_tom 3795
# analyzing the n_tom 3800
# analyzing the n_tom 3805
# analyzing the n_tom 3810
# analyzing the n_tom 3815
# analyzing the n_tom 3820
# analyzing the n_tom 3825
# analyzing the n_tom 3830
# analyzing the n_tom 3835
# analyzing the n_tom 3840
# analyzing the n_tom 3845
# analyzing the n_tom 3850
# analyzing the n_tom 3855
# analyzing the n_tom 3860
# analyzing the n_tom 3865
# analyzing the n_tom 3870
# analyzing the n_tom 3875
# analyzing the n_tom 3880
# analyzing the n_tom 3885
# analyzing the n_tom 3890
# analyzing the n_tom 3895
# analyzing the n_tom 3900
# analyzing the n_tom 3905
# analyzing the n_tom 3910
# analyzing the n_tom 3915
# analyzing the n_tom 3920
# analyzing the n_tom 3925
# analyzing the n_tom 3930
# analyzing the n_tom 3935
# analyzing the n_tom 3940
# analyzing the n_tom 3945
# analyzing the n_tom 3950
# analyzing the n_tom 3955
# analyzing the n_tom 3960
# analyzing the n_tom 3965
# analyzing the n_tom 3970
# analyzing the n_tom 3975
# analyzing the n_tom 3980
# analyzing the n_tom 3985
# analyzing the n_tom 3990
# analyzing the n_tom 3995
# analyzing the n_tom 4000
# analyzing the n_tom 4005
# analyzing the n_tom 4010
# analyzing the n_tom 4015
# analyzing the n_tom 4020
# analyzing the n_tom 4025
# analyzing the n_tom 4030
# analyzing the n_tom 4035
# analyzing the n_tom 4040
# analyzing the n_tom 4045
# analyzing the n_tom 4050
# analyzing the n_tom 4055
# analyzing the n_tom 4060
# analyzing the n_tom 4065
# analyzing the n_tom 4070
# analyzing the n_tom 4075
# analyzing the n_tom 4080
# analyzing the n_tom 4085
# analyzing the n_tom 4090
# analyzing the n_tom 4095
# analyzing the n_tom 4100
# analyzing the n_tom 4105
# analyzing the n_tom 4110
# analyzing the n_tom 4115
# analyzing the n_tom 4120
# analyzing the n_tom 4125
# analyzing the n_tom 4130
# analyzing the n_tom 4135
# analyzing the n_tom 4140
# analyzing the n_tom 4145
# analyzing the n_tom 4150
# analyzing the n_tom 4155
# analyzing the n_tom 4160
# analyzing the n_tom 4165
# analyzing the n_tom 4170
# analyzing the n_tom 4175
# analyzing the n_tom 4180
# analyzing the n_tom 4185
# analyzing the n_tom 4190
# analyzing the n_tom 4195
# analyzing the n_tom 4200
# analyzing the n_tom 4205
# analyzing the n_tom 4210
# analyzing the n_tom 4215
# analyzing the n_tom 4220
# analyzing the n_tom 4225
# analyzing the n_tom 4230
# analyzing the n_tom 4235
# analyzing the n_tom 4240
# analyzing the n_tom 4245
# analyzing the n_tom 4250
# analyzing the n_tom 4255
# analyzing the n_tom 4260
# analyzing the n_tom 4265
# analyzing the n_tom 4270
# analyzing the n_tom 4275
# analyzing the n_tom 4280
# analyzing the n_tom 4285
# analyzing the n_tom 4290
# analyzing the n_tom 4295
# analyzing the n_tom 4300
# analyzing the n_tom 4305
# analyzing the n_tom 4310
# analyzing the n_tom 4315
# analyzing the n_tom 4320
# analyzing the n_tom 4325
# analyzing the n_tom 4330
# analyzing the n_tom 4335
# analyzing the n_tom 4340
# analyzing the n_tom 4345
# analyzing the n_tom 4350
# analyzing the n_tom 4355
# analyzing the n_tom 4360
# analyzing the n_tom 4365
# analyzing the n_tom 4370
# analyzing the n_tom 4375
# analyzing the n_tom 4380
# analyzing the n_tom 4385
# analyzing the n_tom 4390
# analyzing the n_tom 4395
# analyzing the n_tom 4400
# analyzing the n_tom 4405
# analyzing the n_tom 4410
# analyzing the n_tom 4415
# analyzing the n_tom 4420
# analyzing the n_tom 4425
# analyzing the n_tom 4430
# analyzing the n_tom 4435
# analyzing the n_tom 4440
# analyzing the n_tom 4445
# analyzing the n_tom 4450
# analyzing the n_tom 4455
# analyzing the n_tom 4460
# analyzing the n_tom 4465
# analyzing the n_tom 4470
# analyzing the n_tom 4475
# analyzing the n_tom 4480
# analyzing the n_tom 4485
# analyzing the n_tom 4490
# analyzing the n_tom 4495
# analyzing the n_tom 4500
# analyzing the n_tom 4505
# analyzing the n_tom 4510
# analyzing the n_tom 4515
# analyzing the n_tom 4520
# analyzing the n_tom 4525
# analyzing the n_tom 4530
# analyzing the n_tom 4535
# analyzing the n_tom 4540
# analyzing the n_tom 4545
# analyzing the n_tom 4550
# analyzing the n_tom 4555
# analyzing the n_tom 4560
# analyzing the n_tom 4565
# analyzing the n_tom 4570
# analyzing the n_tom 4575
# analyzing the n_tom 4580
# analyzing the n_tom 4585
# analyzing the n_tom 4590
# analyzing the n_tom 4595
# analyzing the n_tom 4600
# analyzing the n_tom 4605
# analyzing the n_tom 4610
# analyzing the n_tom 4615
# analyzing the n_tom 4620
# analyzing the n_tom 4625
# analyzing the n_tom 4630
# analyzing the n_tom 4635
# analyzing the n_tom 4640
# analyzing the n_tom 4645
# analyzing the n_tom 4650
# analyzing the n_tom 4655
# analyzing the n_tom 4660
# analyzing the n_tom 4665
# analyzing the n_tom 4670
# analyzing the n_tom 4675
# analyzing the n_tom 4680
# analyzing the n_tom 4685
# analyzing the n_tom 4690
# analyzing the n_tom 4695
# analyzing the n_tom 4700
# analyzing the n_tom 4705
# analyzing the n_tom 4710
# analyzing the n_tom 4715
# analyzing the n_tom 4720
# analyzing the n_tom 4725
# analyzing the n_tom 4730
# analyzing the n_tom 4735
# analyzing the n_tom 4740
# analyzing the n_tom 4745
# analyzing the n_tom 4750
# analyzing the n_tom 4755
# analyzing the n_tom 4760
# analyzing the n_tom 4765
# analyzing the n_tom 4770
# analyzing the n_tom 4775
# analyzing the n_tom 4780
# analyzing the n_tom 4785
# analyzing the n_tom 4790
# analyzing the n_tom 4795
# analyzing the n_tom 4800
# analyzing the n_tom 4805
# analyzing the n_tom 4810
# analyzing the n_tom 4815
# analyzing the n_tom 4820
# analyzing the n_tom 4825
# analyzing the n_tom 4830
# analyzing the n_tom 4835
# analyzing the n_tom 4840
# analyzing the n_tom 4845
# analyzing the n_tom 4850
# analyzing the n_tom 4855
# analyzing the n_tom 4860
# analyzing the n_tom 4865
# analyzing the n_tom 4870
# analyzing the n_tom 4875
# analyzing the n_tom 4880
# analyzing the n_tom 4885
# analyzing the n_tom 4890
# analyzing the n_tom 4895
# analyzing the n_tom 4900
# analyzing the n_tom 4905
# analyzing the n_tom 4910
# analyzing the n_tom 4915
# analyzing the n_tom 4920
# analyzing the n_tom 4925
# analyzing the n_tom 4930
# analyzing the n_tom 4935
# analyzing the n_tom 4940
# analyzing the n_tom 4945
# analyzing the n_tom 4950
# analyzing the n_tom 4955
# analyzing the n_tom 4960
# analyzing the n_tom 4965
# analyzing the n_tom 4970
# analyzing the n_tom 4975
# analyzing the n_tom 4980
# analyzing the n_tom 4985
# analyzing the n_tom 4990
# analyzing the n_tom 4995
# analyzing the n_tom 5000
# analyzing the n_tom 5005
# analyzing the n_tom 5010
# analyzing the n_tom 5015
# analyzing the n_tom 5020
# analyzing the n_tom 5025
# analyzing the n_tom 5030
# analyzing the n_tom 5035
# analyzing the n_tom 5040
# analyzing the n_tom 5045
# analyzing the n_tom 5050
# analyzing the n_tom 5055
# analyzing the n_tom 5060
# analyzing the n_tom 5065
# analyzing the n_tom 5070
# analyzing the n_tom 5075
# analyzing the n_tom 5080
# analyzing the n_tom 5085
# analyzing the n_tom 5090
# analyzing the n_tom 5095
# analyzing the n_tom 5100
# analyzing the n_tom 5105
# analyzing the n_tom 5110
# analyzing the n_tom 5115
# analyzing the n_tom 5120
# analyzing the n_tom 5125
# analyzing the n_tom 5130
# analyzing the n_tom 5135
# analyzing the n_tom 5140
# analyzing the n_tom 5145
# analyzing the n_tom 5150
# analyzing the n_tom 5155
# analyzing the n_tom 5160
# analyzing the n_tom 5165
# analyzing the n_tom 5170
# analyzing the n_tom 5175
# analyzing the n_tom 5180
# analyzing the n_tom 5185
# analyzing the n_tom 5190
# analyzing the n_tom 5195
# analyzing the n_tom 5200
# analyzing the n_tom 5205
# analyzing the n_tom 5210
# analyzing the n_tom 5215
# analyzing the n_tom 5220
# analyzing the n_tom 5225
# analyzing the n_tom 5230
# analyzing the n_tom 5235
# analyzing the n_tom 5240
# analyzing the n_tom 5245
# analyzing the n_tom 5250
# analyzing the n_tom 5255
# analyzing the n_tom 5260
# analyzing the n_tom 5265
# analyzing the n_tom 5270
# analyzing the n_tom 5275
# analyzing the n_tom 5280
# analyzing the n_tom 5285
# analyzing the n_tom 5290
# analyzing the n_tom 5295
# analyzing the n_tom 5300
# analyzing the n_tom 5305
# analyzing the n_tom 5310
# analyzing the n_tom 5315
# analyzing the n_tom 5320
# analyzing the n_tom 5325
# analyzing the n_tom 5330
# analyzing the n_tom 5335
# analyzing the n_tom 5340
# analyzing the n_tom 5345
# analyzing the n_tom 5350
# analyzing the n_tom 5355
# analyzing the n_tom 5360
# analyzing the n_tom 5365
# analyzing the n_tom 5370
# analyzing the n_tom 5375
# analyzing the n_tom 5380
# analyzing the n_tom 5385
# analyzing the n_tom 5390
# analyzing the n_tom 5395
# analyzing the n_tom 5400
# analyzing the n_tom 5405
# analyzing the n_tom 5410
# analyzing the n_tom 5415
# analyzing the n_tom 5420
# analyzing the n_tom 5425
# analyzing the n_tom 5430
# analyzing the n_tom 5435
# analyzing the n_tom 5440
# analyzing the n_tom 5445
# analyzing the n_tom 5450
# analyzing the n_tom 5455
